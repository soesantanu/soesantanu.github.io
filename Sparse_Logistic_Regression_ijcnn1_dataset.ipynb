# %% [markdown]
# <a href="https://colab.research.google.com/github/soesantanu/soesantanu.github.io/blob/main/Sparse_Logistic_Regression_ijcnn1_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy.linalg as LA
import scipy.sparse as spr
import scipy.sparse.linalg as spr_LA
from time import time
from time import perf_counter
from sklearn import datasets

# %%
# taken from the github of Yura malitsky (graal)
filename = "/content/ijcnn1.bz2"
#filename = "data/real-sim.bz2"
#filename = "data/rcv1_train.binary.bz2"
#filename = "data/kdda.t.bz2"

A, b =  datasets.load_svmlight_file(filename)
m, n = A.shape

print("The dataset {}. The dimensions: m={}, n={}".format(filename[5:], m, n))
# Out:
# The dataset ent/ijcnn1.bz2. The dimensions: m=49990, n=22

# %%
# taken from the github of Yura malitsky (graal)
# define all ingredients for sparse logistic regression
gamma = 0.005 * LA.norm(A.T.dot(b), np.inf)
K = (A.T.multiply(-b)).T.tocsr()

# find the norm of K^T K
L = spr_LA.svds(K, k=1, return_singular_vectors=False)**2

# starting point
x0 = np.zeros(n)


g = lambda x: gamma*LA.norm(x,1)
prox_g = lambda x, rho: x + np.clip(-x, -rho*gamma, rho*gamma)


f = lambda x: np.log(1. + np.exp(x)).sum()

def df(x):
    exp_x = np.exp(x)
    return exp_x/(1.+exp_x)

dh = lambda x, Kx: K.T.dot(df(Kx))

# residual
res = lambda x: LA.norm(x-prox_g(x-dh(x,K.dot(x)), 1))

# energy
J = lambda x, Kx: f(Kx)+g(x)

# prox of g conjugate
def prox_g_conj(v: np.ndarray, gamma: float, sigma: float) -> np.ndarray:
    """
    Proximal operator of tau·g*, where g(x) = lambda*||x||_1 and thus g*(y) = I_{||y||_infty ≤ lambda}.
    Since g* is an indicator, prox_{tau g*}(v) is just the projection onto the l_{infty}-ball of radius lambda.

    Parameters
    ----------
    v : np.ndarray
        Input vector.
    lam : float
        Radius lambda of the l_infinity-ball.
    tau : float
        Step size tau in the proximal operator.

    Returns
    -------
    np.ndarray
        The projected vector onto {y : ||y||_{infty} ≤ lambda}, i.e., elementwise clipped to [−lambda, lambda].
    """
    return np.clip(v, -gamma, gamma)

# %%
import scipy.sparse.linalg as spla

# largest singular value
s_max = spla.svds(K, k=1, return_singular_vectors=False)[0]
L1 = spr_LA.svds(K, k=1, return_singular_vectors=False)**2

L = s_max**2
print("Global Lipschitz constant L =", L1)
print("Local Lipschitz constant L =", L)
# Out:
# Global Lipschitz constant L = [11524.22927676]
# Local Lipschitz constant L = 11524.22927676301

# %%
# The adaptive GRPDA Algorithm

def pd_adaptive_Golden(J, prox_g_conj, K, x0, y0, tau, theta, beta, gamma, tau_max, rho_val, phi, numb_iter=100):
    begin = time()

    x, y, z = x0, y0, x0
    Kx0 = K.dot(x0)
    values = [J(x0, Kx0)]
    tau_prev = tau
    theta_prev = theta
    tt = [0]
    tau_values = []
    sigma_values = []

    for i in range(numb_iter):

        z = x - (1 / phi) * (x - z)
        x1 = z - tau_prev * y - tau_prev * dh(x, K.dot(x))
        Kx1 = K.dot(x1)
        Kx = K.dot(x)
        dhx = dh(x, Kx)
        dhx1 = dh(x1, Kx1)
        x_norm = LA.norm(x - x1)
        dhx_norm = LA.norm(dhx-dhx1)
        if dhx_norm != 0:
            L_bar_prev = (dhx_norm / x_norm) ** 2
            L_current1 = (phi * theta_prev ) / (9*tau_prev)
            L_n = L_current1 /((L_bar_prev + phi * beta))
            tau_n = min(rho_val * tau_prev, L_n, tau_max)
        else:
            tau_n = min(rho_val * tau_prev, tau_max)

        sigma_n = beta * tau_n
        y1 = prox_g_conj(y + sigma_n * x1, gamma, sigma_n)
        print(f"Iteration {i}: J_gap = {J(x1, K.dot(x1))}, tau_n = {tau_n}, x_norm = {LA.norm(x-x1)}, dhx_norm = {dhx_norm}")
        theta_n = phi * (tau_n / tau_prev)
        tau_prev = tau_n
        theta_prev = theta_n
        values.append(J(x1, K.dot(x1)))
        x, y = x1, y1
        tau_values.append(tau_n)  # Store tau_n value
        sigma_values.append(sigma_n)  # Store sigma_n value
        tt.append(time() - begin)
        err = values[-1]
        end = time()
        if err <= 1e-16:
            print ("Iter:", i+1)
            print ("----- Adaptive Golden-Ratio PDA -----")
            print ("Time execution:", round(end - begin,2))
            break
    if err > 1e-16:
      print ("Adaptive Golden-Ratio PDA does not terminate after", round(end - begin,2), "seconds")
    return [values, x, y, tt, sigma_values, tau_values]

# %%
def pd_Golden_Partial_adaptive(J, prox_g_conj, K, x0, y0,
                               mu, mu1, gamma, beta, phi, tau,
                               numb_iter=100, tol=1e-16):
    """
    Golden‑Ratio PDA with partial adaptive step size.

    Solves min_x max_y [ <Kx,y> + g(x) - f*(y) ] using
    a Golden‑Ratio extrapolation and adaptive τₙ based on dh.

    Returns:
      [ values, x, y, tt, sigma_values, tau_values ]
    """
    begin        = time()
    x, y, z      = x0.copy(), y0.copy(), x0.copy()
    values       = [J(x0, K.dot(x0))]
    tt           = [0.0]
    tau_prev     = tau
    tau_values   = []
    sigma_values = []

    for i in range(numb_iter):
        z = x - (1/phi)*(x - z)

        # Compute
        Kx   = K.dot(x)
        x1   = z - tau_prev*y - tau_prev*dh(x, Kx)
        Kx1  = K.dot(x1)
        dhx  = dh(x,  Kx)
        dhx1 = dh(x1, Kx1)

        # 3) Compute norms
        x_norm   = LA.norm(x - x1)
        dhx_norm = LA.norm(dhx - dhx1)

        if dhx_norm !=0:
            tau_n = min(tau_prev,
                        mu/np.sqrt(beta),
                        mu1*(x_norm/dhx_norm))
        else:
            tau_n = min(tau_prev, mu/np.sqrt(beta))
        sigma_n = beta * tau_n

        # 5) Record step sizes
        tau_values.append(tau_n)
        sigma_values.append(sigma_n)

        # 6) Dual update
        y1 = prox_g_conj(y + sigma_n*x1, gamma, sigma_n)

        # 7) Record objective + time
        values.append(J(x1, K.dot(x1)))
        tt.append(time() - begin)
        print(f"Iteration {i}: J_gap = {J(x1, K.dot(x1))}, tau_n = {tau_n}, x_norm = {LA.norm(x-x1)}, Kx_norm = {dhx_norm}")
        # 8) Check convergence
        if values[-1] <= tol:
            print(f"[P‑GRPDA] Converged at iter {i+1}, time {tt[-1]:.3f}s")
            x, y = x1, y1
            break

        # 9) Prepare next iterates
        x, y, tau_prev = x1, y1, tau_n

    else:
        print(f"[P‑GRPDA] Did not converge in {numb_iter} iters (last τ={tau_n:.3e})")

    return [values, x, y, tt, sigma_values, tau_values]

# %%
def pd_Golden(J, prox_g_conj, K,  x0, y0, sigma, tau, gamma, phi, numb_iter=100):
    """
    Golden-Ratio Primal-dual algorithm for the problem min_x
    max_y [<Kx,y> + g(x) - f*(y)]
    J denotes some function which we compute in every iteration to
    study perfomance. It may be energy, primal-dual gap, etc.
    """
    begin = time()

    x, y, z = x0, y0, x0
    values = [J(x0,K.dot(x0))]
    tau_values = []
    sigma_values = []
    tt = [0]

    for i in range(numb_iter):
        z = x-(1/phi)*(x - z)
        Kx = K.dot(x)
        x = z - tau * y - tau * dh(x, Kx)

        y = prox_g_conj(y + sigma * x, gamma, sigma)

        values.append(J(x, K.dot(x)))
        tau_values.append(tau)
        sigma_values.append(sigma)
        print(f"Iteration {i}: J_gap = {J(x, K.dot(x))}, tau = {tau}, phi = {phi}")
        tt.append(time() - begin)
        err = values[-1]
        end = time()
        if err <= 1e-16:
            print ("Iter:", i+1)
            print ("----- Golden-Ratio Primal-dual method -----")
            print ("Time execution:", round(end - begin,2))
            break
    if err > 1e-16:
      print ("Golden-Ratio Primal-dual method does not terminate after", round(end - begin,2), "seconds")
    return [values, x, y,tt, sigma_values, tau_values]

# %%
def pd(J, prox_g_conj, K,  x0, y0, sigma, tau, gamma, numb_iter=100):
    """
    Primal-dual algorithm of Pock and Chambolle for the problem min_x
    max_y [<Kx,y> + g(x) - f*(y)]
    J denotes some function which we compute in every iteration to
    study perfomance. It may be energy, primal-dual gap, etc.
    """
    begin = time()
    theta = 1.0
    x, y, z = x0, y0, x0
    values = [J(x0, K.dot(x0))]
    sigma_values = []
    tau_values = []
    tt = [0]

    for i in range(numb_iter):
        Kx = K.dot(x)
        x1 = x - tau * y- tau * dh(x, Kx)
        z = x1 + theta * (x1 - x)
        y = prox_g_conj(y + sigma * z, gamma, sigma)
        print(f"Iteration {i}: J_gap = {J(x, K.dot(x))}, tau = {tau}, sigma = {sigma}, theta = {theta}")
        x = x1
        values.append(J(x, K.dot(x)))
        sigma_values.append(sigma)
        tau_values.append(tau)

        tt.append(time() - begin)
        err = values[-1]
        end = time()
        if err <= 1e-16:
            print ("Iter:", i+1)
            print ("----- Primal-dual method -----")
            print ("Time execution:", round(end - begin,2))
            break
    if err > 1e-16:
      print ("Primal-dual method does not terminate after", round(end - begin,2), "seconds")

    return [values, x, y,tt, tau_values, sigma_values]

# %%
N = 5000
tau = 1.000e-03  #3.162e+06, τ=5.623e-06
tau_agraal = 1e-5
tau_pgrpda = 9e-3
beta_pgrpda = 3.5e6
x0 = np.zeros(n)
y0 = x0 + np.random.randn(x0.shape[0]) * 1e-9
theta = 1
beta = 4.642e+03
tau_max = 100000000
phi = 1.5
rho_val = 1/phi + (1/phi**2)
phi_pgrpda = 1.76
mu = 0.79
mu1 = 0.26
tau_egrpda = 6.32e-04
sigma_egrpda = 2.78e+00
phi_egrpda = (1 + np.sqrt(5))/2
sigma_pd = 2
tau_pd = 6.5e-5
# Run all the algorithms
ans4 = pd_adaptive_Golden(J, prox_g_conj, K, x0, y0, tau, theta, beta, gamma, tau_max, rho_val, phi, numb_iter=N)
ans1 = pd_Golden(J, prox_g_conj, K,  x0, y0, sigma_egrpda, tau_egrpda, gamma, phi_egrpda, numb_iter=N)
ans5 = pd_Golden_Partial_adaptive(J, prox_g_conj, K, x0, y0, mu, mu1, gamma, beta_pgrpda, phi_pgrpda, tau_pgrpda, numb_iter=N)
ans2 = pd(J, prox_g_conj, K,  x0, y0, sigma_pd, tau_pd, gamma, numb_iter=N)
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteration 1: J_gap = 29731.841084879605, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 2: J_gap = 26419.66119779266, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 3: J_gap = 24134.7266855636, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4: J_gap = 22511.112057200793, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 5: J_gap = 21323.60613370475, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 6: J_gap = 20432.121861987423, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 7: J_gap = 19747.29722792996, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 8: J_gap = 19210.437427570832, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 9: J_gap = 18781.946826217096, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 10: J_gap = 18434.402600472902, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 11: J_gap = 18148.367878369536, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 12: J_gap = 17909.82094843104, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 13: J_gap = 17708.36821717459, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 14: J_gap = 17536.245404324647, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 15: J_gap = 17387.55923239847, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 16: J_gap = 17257.776313847942, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 17: J_gap = 17143.369775295265, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 18: J_gap = 17041.485962842897, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 19: J_gap = 16949.875517199274, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 20: J_gap = 16866.832723702144, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 21: J_gap = 16790.98119388725, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 22: J_gap = 16721.20298461278, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 23: J_gap = 16656.584680062926, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 24: J_gap = 16596.375966706884, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 25: J_gap = 16539.95751291134, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 26: J_gap = 16486.815850979212, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 27: J_gap = 16436.523580133893, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 28: J_gap = 16388.723649222058, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 29: J_gap = 16343.116793760348, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 30: J_gap = 16299.451431002879, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 31: J_gap = 16257.515484492504, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 32: J_gap = 16217.12973363314, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 33: J_gap = 16178.142376389413, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 34: J_gap = 16140.424562862818, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 35: J_gap = 16103.866710303198, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 36: J_gap = 16068.37545045797, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 37: J_gap = 16033.847500338732, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 38: J_gap = 16000.184111984705, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 39: J_gap = 15967.23542514426, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 40: J_gap = 15934.892940864966, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 41: J_gap = 15903.123460960993, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 42: J_gap = 15871.897793732254, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 43: J_gap = 15841.190204904267, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 44: J_gap = 15810.977948059775, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 45: J_gap = 15781.24086227941, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 46: J_gap = 15751.961026750147, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 47: J_gap = 15723.122463776355, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 48: J_gap = 15694.71088300928, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 49: J_gap = 15666.713460852363, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 50: J_gap = 15639.118649946473, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 51: J_gap = 15611.895145786018, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 52: J_gap = 15585.011347497335, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 53: J_gap = 15558.458747785986, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 54: J_gap = 15532.241523960449, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 55: J_gap = 15506.368513347286, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 56: J_gap = 15480.80588057957, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 57: J_gap = 15455.547606516657, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 58: J_gap = 15430.588119240205, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 59: J_gap = 15405.922239414622, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 60: J_gap = 15381.5451326015, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 61: J_gap = 15357.452267619377, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 62: J_gap = 15333.639380164552, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 63: J_gap = 15310.102441015133, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 64: J_gap = 15286.827853495679, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 65: J_gap = 15263.803226012355, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 66: J_gap = 15241.02520618194, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 67: J_gap = 15218.490590257466, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 68: J_gap = 15196.196306220938, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 69: J_gap = 15174.139398954341, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 70: J_gap = 15152.317017232488, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 71: J_gap = 15130.726402313936, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 72: J_gap = 15109.3648779346, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 73: J_gap = 15088.22984153324, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 74: J_gap = 15067.318756559383, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 75: J_gap = 15046.629145732793, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 76: J_gap = 15026.158585139769, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 77: J_gap = 15005.904699065657, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 78: J_gap = 14985.86515547521, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 79: J_gap = 14966.037662063178, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 80: J_gap = 14946.419262043535, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 81: J_gap = 14927.003062372347, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 82: J_gap = 14907.78700437035, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 83: J_gap = 14888.769055793831, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 84: J_gap = 14869.947208658166, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 85: J_gap = 14851.31947735494, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 86: J_gap = 14832.883897027388, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 87: J_gap = 14814.638522173154, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 88: J_gap = 14796.58142544693, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 89: J_gap = 14778.710696638684, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 90: J_gap = 14761.024441806116, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 91: J_gap = 14743.52078254231, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 92: J_gap = 14726.197855361881, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 93: J_gap = 14709.05381119073, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 94: J_gap = 14692.086814946277, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 95: J_gap = 14675.295045196559, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 96: J_gap = 14658.676693887872, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 97: J_gap = 14642.229966131847, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 98: J_gap = 14625.95308004388, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 99: J_gap = 14609.844266625785, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 100: J_gap = 14593.901769686288, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 101: J_gap = 14578.12384579383, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 102: J_gap = 14562.508764256656, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 103: J_gap = 14547.054807125896, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 104: J_gap = 14531.760269217639, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 105: J_gap = 14516.623458150727, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 106: J_gap = 14501.64269439713, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 107: J_gap = 14486.816311342374, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 108: J_gap = 14472.142655353542, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 109: J_gap = 14457.620085852932, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 110: J_gap = 14443.246975395488, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 111: J_gap = 14429.021709748497, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 112: J_gap = 14414.942687972107, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 113: J_gap = 14401.008066847546, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 114: J_gap = 14387.215396075884, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 115: J_gap = 14373.563130145361, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 116: J_gap = 14360.049736984349, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 117: J_gap = 14346.67369799398, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 118: J_gap = 14333.432944913828, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 119: J_gap = 14320.32589371488, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 120: J_gap = 14307.351059941493, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 121: J_gap = 14294.506973002095, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 122: J_gap = 14281.792176146231, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 123: J_gap = 14269.205226441585, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 124: J_gap = 14256.744694750567, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 125: J_gap = 14244.409165705947, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 126: J_gap = 14232.197237685265, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 127: J_gap = 14220.107522783583, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 128: J_gap = 14208.138646784457, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 129: J_gap = 14196.289249128817, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 130: J_gap = 14184.55798288158, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 131: J_gap = 14172.943514695897, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 132: J_gap = 14161.444524774886, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 133: J_gap = 14150.05970683078, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 134: J_gap = 14138.787768041415, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 135: J_gap = 14127.627429004038, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 136: J_gap = 14116.577423686394, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 137: J_gap = 14105.636499375121, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 138: J_gap = 14094.803416621404, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 139: J_gap = 14084.076949183982, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 140: J_gap = 14073.455883969511, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 141: J_gap = 14062.939020970301, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 142: J_gap = 14052.525173199561, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 143: J_gap = 14042.213166624097, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 144: J_gap = 14032.001840094657, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 145: J_gap = 14021.890045273905, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 146: J_gap = 14011.876646562116, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 147: J_gap = 14001.960521020725, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 148: J_gap = 13992.140558293744, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 149: J_gap = 13982.415660527182, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 150: J_gap = 13972.78474228653, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 151: J_gap = 13963.24673047241, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 152: J_gap = 13953.800564234469, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 153: J_gap = 13944.445194883621, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 154: J_gap = 13935.179585802718, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 155: J_gap = 13926.002712355723, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 156: J_gap = 13916.913561795509, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 157: J_gap = 13907.91113317035, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 158: J_gap = 13898.994437229172, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 159: J_gap = 13890.162496325695, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 160: J_gap = 13881.4143443215, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 161: J_gap = 13872.749026488156, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 162: J_gap = 13864.165599408412, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 163: J_gap = 13855.663130876626, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 164: J_gap = 13847.24069979843, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 165: J_gap = 13838.897396089738, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 166: J_gap = 13830.63232057517, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 167: J_gap = 13822.444584885976, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 168: J_gap = 13814.333311357459, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 169: J_gap = 13806.297632926073, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 170: J_gap = 13798.336693026165, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 171: J_gap = 13790.44964548648, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 172: J_gap = 13782.635654426444, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 173: J_gap = 13774.893894152316, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 174: J_gap = 13767.223549053291, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 175: J_gap = 13759.623813497496, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 176: J_gap = 13752.160742539749, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 177: J_gap = 13744.797371361889, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 178: J_gap = 13737.50157866894, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 179: J_gap = 13730.272604021751, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 180: J_gap = 13723.109696255802, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 181: J_gap = 13716.012113384515, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 182: J_gap = 13708.979122502682, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 183: J_gap = 13702.009999689992, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 184: J_gap = 13695.10402991471, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 185: J_gap = 13688.260506937542, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 186: J_gap = 13681.478733215763, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 187: J_gap = 13674.758019807576, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 188: J_gap = 13668.097686276815, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 189: J_gap = 13661.497060597963, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 190: J_gap = 13654.955479061555, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 191: J_gap = 13648.472286179978, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 192: J_gap = 13642.046834593693, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 193: J_gap = 13635.678484977929, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 194: J_gap = 13629.366605949868, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 195: J_gap = 13623.110573976308, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 196: J_gap = 13616.909773281877, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 197: J_gap = 13610.763595757802, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 198: J_gap = 13604.671440871243, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 199: J_gap = 13598.632715575222, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 200: J_gap = 13592.646834219153, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 201: J_gap = 13586.713218460027, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 202: J_gap = 13580.831297174183, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 203: J_gap = 13575.000506369814, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 204: J_gap = 13569.220289100062, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 205: J_gap = 13563.490095376863, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 206: J_gap = 13557.809382085441, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 207: J_gap = 13552.177612899526, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 208: J_gap = 13546.594258197285, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 209: J_gap = 13541.058794977987, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 210: J_gap = 13535.570706779374, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 211: J_gap = 13530.129483595798, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 212: J_gap = 13524.73462179709, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 213: J_gap = 13519.385624048182, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 214: J_gap = 13514.081999229491, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 215: J_gap = 13508.82326235807, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 216: J_gap = 13503.608934509504, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 217: J_gap = 13498.438542740598, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 218: J_gap = 13493.311620012824, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 219: J_gap = 13488.227705116557, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 220: J_gap = 13483.186342596066, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 221: J_gap = 13478.187082675302, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 222: J_gap = 13473.229481184448, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 223: J_gap = 13468.313099487263, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 224: J_gap = 13463.437504409198, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 225: J_gap = 13458.60226816629, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 226: J_gap = 13453.806968294819, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 227: J_gap = 13449.0511875818, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 228: J_gap = 13444.334513996138, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 229: J_gap = 13439.65654062069, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 230: J_gap = 13435.016865584981, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 231: J_gap = 13430.41509199877, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 232: J_gap = 13425.85082788634, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 233: J_gap = 13421.323686121548, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 234: J_gap = 13416.833284363669, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 235: J_gap = 13412.379244993946, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 236: J_gap = 13407.961195052938, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 237: J_gap = 13403.578766178594, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 238: J_gap = 13399.231594545057, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 239: J_gap = 13394.91932080224, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 240: J_gap = 13390.641590016116, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 241: J_gap = 13386.39805160974, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 242: J_gap = 13382.188359304982, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 243: J_gap = 13378.012171065038, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 244: J_gap = 13373.869149037566, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 245: J_gap = 13369.758959498617, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 246: J_gap = 13365.681272797221, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 247: J_gap = 13361.636001917552, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 248: J_gap = 13357.62291498061, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 249: J_gap = 13353.641679017059, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 250: J_gap = 13349.691965491718, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 251: J_gap = 13345.773450225075, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 252: J_gap = 13341.885813317, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 253: J_gap = 13338.028739072506, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 254: J_gap = 13334.201915929552, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 255: J_gap = 13330.405036388704, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 256: J_gap = 13326.637796944644, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 257: J_gap = 13322.8998980194, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 258: J_gap = 13319.191043897263, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 259: J_gap = 13315.510942661267, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 260: J_gap = 13311.859306131257, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 261: J_gap = 13308.235849803366, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 262: J_gap = 13304.640292790958, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 263: J_gap = 13301.072357766887, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 264: J_gap = 13297.53177090711, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 265: J_gap = 13294.01826183551, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 266: J_gap = 13290.531563569974, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 267: J_gap = 13287.071412469611, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 268: J_gap = 13283.637548183122, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 269: J_gap = 13280.229713598234, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 270: J_gap = 13276.84765479221, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 271: J_gap = 13273.491120983359, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 272: J_gap = 13270.159864483543, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 273: J_gap = 13266.853640651629, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 274: J_gap = 13263.572207847863, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 275: J_gap = 13260.315327389131, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 276: J_gap = 13257.082763505105, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 277: J_gap = 13253.87428329522, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 278: J_gap = 13250.689656686436, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 279: J_gap = 13247.528656391847, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 280: J_gap = 13244.391057870027, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 281: J_gap = 13241.276639285104, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 282: J_gap = 13238.185181467605, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 283: J_gap = 13235.116467875972, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 284: J_gap = 13232.070284558784, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 285: J_gap = 13229.046420117644, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 286: J_gap = 13226.044665670697, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 287: J_gap = 13223.064814816835, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 288: J_gap = 13220.106663600462, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 289: J_gap = 13217.170010476893, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 290: J_gap = 13214.254656278366, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 291: J_gap = 13211.360404180554, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 292: J_gap = 13208.487059669716, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 293: J_gap = 13205.634430510374, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 294: J_gap = 13202.802326713483, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 295: J_gap = 13199.990560505192, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 296: J_gap = 13197.198946296045, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 297: J_gap = 13194.427300650757, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 298: J_gap = 13191.675442258416, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 299: J_gap = 13188.943191903183, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 300: J_gap = 13186.230372435486, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 301: J_gap = 13183.536808743633, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 302: J_gap = 13180.8623277259, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 303: J_gap = 13178.206758263033, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 304: J_gap = 13175.56993119122, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 305: J_gap = 13172.95167927544, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 306: J_gap = 13170.351837183269, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 307: J_gap = 13167.770241459035, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 308: J_gap = 13165.206730498438, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 309: J_gap = 13162.661144523492, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 310: J_gap = 13160.133325557916, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 311: J_gap = 13157.623117402834, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 312: J_gap = 13155.130365612895, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 313: J_gap = 13152.654917472712, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 314: J_gap = 13150.196621973704, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 315: J_gap = 13147.755329791236, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 316: J_gap = 13145.330893262118, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 317: J_gap = 13142.923166362478, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 318: J_gap = 13140.532004685876, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 319: J_gap = 13138.157265421854, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 320: J_gap = 13135.798807334697, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 321: J_gap = 13133.456490742581, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 322: J_gap = 13131.130177497009, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 323: J_gap = 13128.819730962507, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 324: J_gap = 13126.52501599669, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 325: J_gap = 13124.245898930567, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 326: J_gap = 13121.982247549131, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 327: J_gap = 13119.733931072278, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 328: J_gap = 13117.500820135949, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 329: J_gap = 13115.282786773585, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 330: J_gap = 13113.079704397813, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 331: J_gap = 13110.891447782451, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 332: J_gap = 13108.7178930447, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 333: J_gap = 13106.558917627666, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 334: J_gap = 13104.414400283078, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 335: J_gap = 13102.28422105428, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 336: J_gap = 13100.168261259465, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 337: J_gap = 13098.06640347514, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 338: J_gap = 13095.97853151984, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 339: J_gap = 13093.904530438056, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 340: J_gap = 13091.844286484418, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 341: J_gap = 13089.797687108077, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 342: J_gap = 13087.764620937322, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 343: J_gap = 13085.744977764425, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 344: J_gap = 13083.738648530682, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 345: J_gap = 13081.745525311666, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 346: J_gap = 13079.765501302725, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 347: J_gap = 13077.79847080463, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 348: J_gap = 13075.844329209469, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 349: J_gap = 13073.902972986732, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 350: J_gap = 13071.974299669557, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 351: J_gap = 13070.058207841254, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 352: J_gap = 13068.154597121891, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 353: J_gap = 13066.263368155218, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 354: J_gap = 13064.384422595644, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 355: J_gap = 13062.517663095481, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 356: J_gap = 13060.662993292337, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 357: J_gap = 13058.82031779668, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 358: J_gap = 13056.989542179599, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 359: J_gap = 13055.170572960702, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 360: J_gap = 13053.363317596242, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 361: J_gap = 13051.56768446734, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 362: J_gap = 13049.783582868407, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 363: J_gap = 13048.010922995763, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 364: J_gap = 13046.249615936344, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 365: J_gap = 13044.499573656614, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 366: J_gap = 13042.760708991633, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 367: J_gap = 13041.032935634254, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 368: J_gap = 13039.316168124487, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 369: J_gap = 13037.610321839009, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 370: J_gap = 13035.915312980827, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 371: J_gap = 13034.294319101606, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 372: J_gap = 13032.722301176027, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 373: J_gap = 13031.160487481331, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 374: J_gap = 13029.60878800372, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 375: J_gap = 13028.067113585872, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 376: J_gap = 13026.535375918787, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 377: J_gap = 13025.013487533675, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 378: J_gap = 13023.501361793979, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 379: J_gap = 13021.998912887457, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 380: J_gap = 13020.506055818378, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 381: J_gap = 13019.022706399795, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 382: J_gap = 13017.566623982297, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 383: J_gap = 13016.127768566968, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 384: J_gap = 13014.69799794277, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 385: J_gap = 13013.277228312752, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 386: J_gap = 13011.865376679001, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 387: J_gap = 13010.462360835747, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 388: J_gap = 13009.068099362557, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 389: J_gap = 13007.682511617608, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 390: J_gap = 13006.305517731005, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 391: J_gap = 13004.937038598222, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 392: J_gap = 13003.576995873555, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 393: J_gap = 13002.2253119637, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 394: J_gap = 13000.899163794893, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 395: J_gap = 12999.66263235531, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 396: J_gap = 12998.43365123733, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 397: J_gap = 12997.212136811475, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 398: J_gap = 12995.998006271182, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 399: J_gap = 12994.79117762728, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 400: J_gap = 12993.591569702505, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 401: J_gap = 12992.399102126117, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 402: J_gap = 12991.213695328515, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 403: J_gap = 12990.035270535964, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 404: J_gap = 12988.863749765338, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 405: J_gap = 12987.699055818919, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 406: J_gap = 12986.541112279281, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 407: J_gap = 12985.38984350417, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 408: J_gap = 12984.245174621494, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 409: J_gap = 12983.107031524312, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 410: J_gap = 12981.97534086589, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 411: J_gap = 12980.850030054804, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 412: J_gap = 12979.73102725009, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 413: J_gap = 12978.618261356442, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 414: J_gap = 12977.511662019413, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 415: J_gap = 12976.411159620726, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 416: J_gap = 12975.316685273558, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 417: J_gap = 12974.228170817927, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 418: J_gap = 12973.145548816046, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 419: J_gap = 12972.068752547788, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 420: J_gap = 12970.997716006126, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 421: J_gap = 12969.932373892661, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 422: J_gap = 12968.87266161313, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 423: J_gap = 12967.818515272997, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 424: J_gap = 12966.769871673048, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 425: J_gap = 12965.741792893903, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 426: J_gap = 12964.751882690214, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 427: J_gap = 12963.766981677452, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 428: J_gap = 12962.787025182428, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 429: J_gap = 12961.811949256156, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 430: J_gap = 12960.841690669968, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 431: J_gap = 12959.876186911612, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 432: J_gap = 12958.915376181392, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 433: J_gap = 12957.959197388336, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 434: J_gap = 12957.007590146335, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 435: J_gap = 12956.060494770358, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 436: J_gap = 12955.117852272646, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 437: J_gap = 12954.179604358935, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 438: J_gap = 12953.245693424667, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 439: J_gap = 12952.31606255128, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 440: J_gap = 12951.390655502424, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 441: J_gap = 12950.46941672025, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 442: J_gap = 12949.55229132171, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 443: J_gap = 12948.639225094827, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 444: J_gap = 12947.730164495002, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 445: J_gap = 12946.825056641337, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 446: J_gap = 12945.923849312963, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 447: J_gap = 12945.026490945347, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 448: J_gap = 12944.132930626663, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 449: J_gap = 12943.243118094098, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 450: J_gap = 12942.357003730245, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 451: J_gap = 12941.474538559429, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 452: J_gap = 12940.59567424409, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 453: J_gap = 12939.720363081136, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 454: J_gap = 12938.848557998332, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 455: J_gap = 12937.98021255066, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 456: J_gap = 12937.1152809167, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 457: J_gap = 12936.253717895028, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 458: J_gap = 12935.395478900584, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 459: J_gap = 12934.540519961067, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 460: J_gap = 12933.688797713323, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 461: J_gap = 12932.84026939973, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 462: J_gap = 12931.994892864594, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 463: J_gap = 12931.152626550536, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 464: J_gap = 12930.31342949489, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 465: J_gap = 12929.47726132608, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 466: J_gap = 12928.644082260027, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 467: J_gap = 12927.813853096535, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 468: J_gap = 12926.986535215663, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 469: J_gap = 12926.16209057414, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 470: J_gap = 12925.340481701718, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 471: J_gap = 12924.521671697594, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 472: J_gap = 12923.70562422675, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 473: J_gap = 12922.892303516368, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 474: J_gap = 12922.081674352185, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 475: J_gap = 12921.273702074866, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 476: J_gap = 12920.468352576394, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 477: J_gap = 12919.665592296416, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 478: J_gap = 12918.86538821862, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 479: J_gap = 12918.067707867092, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 480: J_gap = 12917.272519302667, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 481: J_gap = 12916.4797911193, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 482: J_gap = 12915.68949244039, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 483: J_gap = 12914.90159291515, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 484: J_gap = 12914.116062714938, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 485: J_gap = 12913.332872529594, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 486: J_gap = 12912.551993563771, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 487: J_gap = 12911.773397533274, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 488: J_gap = 12910.997056661374, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 489: J_gap = 12910.22294367514, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 490: J_gap = 12909.451031801742, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 491: J_gap = 12908.68129476477, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 492: J_gap = 12907.913706780557, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 493: J_gap = 12907.148242554444, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 494: J_gap = 12906.384877277118, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 495: J_gap = 12905.623586620884, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 496: J_gap = 12904.86434673597, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 497: J_gap = 12904.107134246802, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 498: J_gap = 12903.35192624828, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 499: J_gap = 12902.598700302085, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 500: J_gap = 12901.847434432919, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 501: J_gap = 12901.09810712479, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 502: J_gap = 12900.350697317284, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 503: J_gap = 12899.605184401828, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 504: J_gap = 12898.861548217923, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 505: J_gap = 12898.119769049425, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 506: J_gap = 12897.379827620804, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 507: J_gap = 12896.641705093347, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 508: J_gap = 12895.905383061467, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 509: J_gap = 12895.17084354889, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 510: J_gap = 12894.438069004915, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 511: J_gap = 12893.707042300664, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 512: J_gap = 12892.977746725292, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 513: J_gap = 12892.250165982221, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 514: J_gap = 12891.524284185396, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 515: J_gap = 12890.80008585547, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 516: J_gap = 12890.077555916065, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 517: J_gap = 12889.356679689969, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 518: J_gap = 12888.637442895371, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 519: J_gap = 12887.919831642084, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 520: J_gap = 12887.203832427746, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 521: J_gap = 12886.489432134056, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 522: J_gap = 12885.776618022983, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 523: J_gap = 12885.06537773298, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 524: J_gap = 12884.35569927521, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 525: J_gap = 12883.647571029745, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 526: J_gap = 12882.9409817418, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 527: J_gap = 12882.235920517931, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 528: J_gap = 12881.532376822275, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 529: J_gap = 12880.830340472741, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 530: J_gap = 12880.129801637248, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 531: J_gap = 12879.430750829935, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 532: J_gap = 12878.733178907389, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 533: J_gap = 12878.037077064866, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 534: J_gap = 12877.342436832505, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 535: J_gap = 12876.649250071572, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 536: J_gap = 12875.957508970683, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 537: J_gap = 12875.267206042035, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 538: J_gap = 12874.578334117637, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 539: J_gap = 12873.890886345564, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 540: J_gap = 12873.204856186177, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 541: J_gap = 12872.5202374084, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 542: J_gap = 12871.83702408593, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 543: J_gap = 12871.155210593528, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 544: J_gap = 12870.474791603261, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 545: J_gap = 12869.79576208077, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 546: J_gap = 12869.118117281529, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 547: J_gap = 12868.441852747137, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 548: J_gap = 12867.76696430159, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 549: J_gap = 12867.093448047559, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 550: J_gap = 12866.421300362694, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 551: J_gap = 12865.750517895924, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 552: J_gap = 12865.081097563747, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 553: J_gap = 12864.41303654656, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 554: J_gap = 12863.746332284976, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 555: J_gap = 12863.080982476135, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 556: J_gap = 12862.416985070062, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 557: J_gap = 12861.754338266002, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 558: J_gap = 12861.093040508764, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 559: J_gap = 12860.43309048509, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 560: J_gap = 12859.774487120025, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 561: J_gap = 12859.11722957329, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 562: J_gap = 12858.461317235677, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 563: J_gap = 12857.806749725445, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 564: J_gap = 12857.153526884715, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 565: J_gap = 12856.501648775913, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 566: J_gap = 12855.851115678182, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 567: J_gap = 12855.20192808382, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 568: J_gap = 12854.554086694738, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 569: J_gap = 12853.907592418918, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 570: J_gap = 12853.262446366896, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 571: J_gap = 12852.61864984822, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 572: J_gap = 12851.976204367988, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 573: J_gap = 12851.33511162332, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 574: J_gap = 12850.695373499904, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 575: J_gap = 12850.056992068518, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 576: J_gap = 12849.419969581588, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 577: J_gap = 12848.784308469743, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 578: J_gap = 12848.150011338386, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 579: J_gap = 12847.517080964299, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 580: J_gap = 12846.88552029222, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 581: J_gap = 12846.255332431492, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 582: J_gap = 12845.626520652662, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 583: J_gap = 12844.999088384151, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 584: J_gap = 12844.373039208906, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 585: J_gap = 12843.748376861073, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 586: J_gap = 12843.125105222698, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 587: J_gap = 12842.503228320425, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 588: J_gap = 12841.882750322222, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 589: J_gap = 12841.26367553413, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 590: J_gap = 12840.646008396994, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 591: J_gap = 12840.02975348326, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 592: J_gap = 12839.414915493759, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 593: J_gap = 12838.820749731298, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 594: J_gap = 12838.230018843951, tau = 6.5e-05, sigma = 2, theta = 1.0
# ...
# Iteration 4806: J_gap = 12697.76121985565, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4807: J_gap = 12697.761080539269, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4808: J_gap = 12697.760941010369, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4809: J_gap = 12697.76080128635, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4810: J_gap = 12697.760661384587, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4811: J_gap = 12697.760521322445, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4812: J_gap = 12697.760381117245, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4813: J_gap = 12697.7602407863, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4814: J_gap = 12697.760100346884, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4815: J_gap = 12697.759959816256, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4816: J_gap = 12697.759819211626, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4817: J_gap = 12697.759678550181, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4818: J_gap = 12697.759537849068, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4819: J_gap = 12697.759397125394, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4820: J_gap = 12697.759256396232, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4821: J_gap = 12697.759115678606, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4822: J_gap = 12697.758974989503, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4823: J_gap = 12697.758834345852, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4824: J_gap = 12697.758693764546, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4825: J_gap = 12697.758553262425, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4826: J_gap = 12697.758412856268, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4827: J_gap = 12697.758272562809, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4828: J_gap = 12697.758132398723, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4829: J_gap = 12697.75799238062, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4830: J_gap = 12697.757852525065, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4831: J_gap = 12697.757712848545, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4832: J_gap = 12697.757573367488, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4833: J_gap = 12697.75743409826, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4834: J_gap = 12697.757298857558, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4835: J_gap = 12697.757276539432, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4836: J_gap = 12697.757254052314, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4837: J_gap = 12697.757272288156, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4838: J_gap = 12697.757331745084, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4839: J_gap = 12697.757390770374, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4840: J_gap = 12697.757449357057, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4841: J_gap = 12697.757507498254, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4842: J_gap = 12697.75756518714, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4843: J_gap = 12697.757622416975, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4844: J_gap = 12697.757679181088, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4845: J_gap = 12697.757735472882, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4846: J_gap = 12697.757791285841, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4847: J_gap = 12697.757846613516, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4848: J_gap = 12697.757901449544, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4849: J_gap = 12697.757955787634, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4850: J_gap = 12697.758009621568, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4851: J_gap = 12697.758062945217, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4852: J_gap = 12697.758115752518, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4853: J_gap = 12697.758168037504, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4854: J_gap = 12697.75821979428, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4855: J_gap = 12697.758271017023, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4856: J_gap = 12697.758321700001, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4857: J_gap = 12697.758371837564, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4858: J_gap = 12697.758421424141, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4859: J_gap = 12697.758470454246, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4860: J_gap = 12697.758518922474, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4861: J_gap = 12697.7585668235, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4862: J_gap = 12697.758614152095, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4863: J_gap = 12697.758660903106, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4864: J_gap = 12697.758707071469, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4865: J_gap = 12697.75875265219, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4866: J_gap = 12697.758797640392, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4867: J_gap = 12697.758842031257, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4868: J_gap = 12697.758885820065, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4869: J_gap = 12697.758929002184, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4870: J_gap = 12697.758971573066, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4871: J_gap = 12697.759013528252, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4872: J_gap = 12697.759054863374, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4873: J_gap = 12697.759095574145, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4874: J_gap = 12697.759135656379, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4875: J_gap = 12697.759175105968, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4876: J_gap = 12697.759213918902, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4877: J_gap = 12697.759252091259, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4878: J_gap = 12697.759289619198, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4879: J_gap = 12697.759326498985, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4880: J_gap = 12697.759362726963, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4881: J_gap = 12697.759398299575, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4882: J_gap = 12697.759433213347, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4883: J_gap = 12697.7594674649, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4884: J_gap = 12697.759501050954, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4885: J_gap = 12697.75953396831, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4886: J_gap = 12697.759566213863, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4887: J_gap = 12697.759597784612, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4888: J_gap = 12697.759628677633, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4889: J_gap = 12697.7596588901, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4890: J_gap = 12697.759688419283, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4891: J_gap = 12697.759717262541, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4892: J_gap = 12697.759745417332, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4893: J_gap = 12697.759772881198, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4894: J_gap = 12697.75979965178, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4895: J_gap = 12697.759825726811, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4896: J_gap = 12697.759851104121, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4897: J_gap = 12697.759959478719, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4898: J_gap = 12697.76009674753, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4899: J_gap = 12697.760232767108, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4900: J_gap = 12697.760367522847, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4901: J_gap = 12697.760501000343, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4902: J_gap = 12697.760633185388, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4903: J_gap = 12697.760820644595, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4904: J_gap = 12697.761018552814, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4905: J_gap = 12697.761214514627, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4906: J_gap = 12697.761408510083, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4907: J_gap = 12697.761600519545, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4908: J_gap = 12697.76179052367, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4909: J_gap = 12697.761978503433, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4910: J_gap = 12697.762164440119, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4911: J_gap = 12697.762348315322, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4912: J_gap = 12697.762530110955, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4913: J_gap = 12697.76270980924, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4914: J_gap = 12697.76288739272, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4915: J_gap = 12697.763062844262, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4916: J_gap = 12697.763236147044, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4917: J_gap = 12697.763407284569, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4918: J_gap = 12697.763576240655, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4919: J_gap = 12697.763742999457, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4920: J_gap = 12697.76390754545, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4921: J_gap = 12697.764069863433, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4922: J_gap = 12697.764229938526, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4923: J_gap = 12697.76438775619, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4924: J_gap = 12697.76454330221, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4925: J_gap = 12697.7646965627, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4926: J_gap = 12697.764847524102, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4927: J_gap = 12697.764996173195, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4928: J_gap = 12697.765142497095, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4929: J_gap = 12697.765286483242, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4930: J_gap = 12697.765428119419, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4931: J_gap = 12697.765567393733, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4932: J_gap = 12697.765704294645, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4933: J_gap = 12697.76583881093, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4934: J_gap = 12697.765970931725, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4935: J_gap = 12697.766100646484, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4936: J_gap = 12697.766227945003, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4937: J_gap = 12697.766352817425, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4938: J_gap = 12697.76647525423, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4939: J_gap = 12697.766595246225, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4940: J_gap = 12697.766712784574, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4941: J_gap = 12697.766827860769, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4942: J_gap = 12697.766940466649, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4943: J_gap = 12697.76705059439, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4944: J_gap = 12697.767158236502, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4945: J_gap = 12697.767263385846, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4946: J_gap = 12697.767366035618, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4947: J_gap = 12697.767466179357, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4948: J_gap = 12697.767563810941, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4949: J_gap = 12697.76765892459, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4950: J_gap = 12697.767751514857, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4951: J_gap = 12697.767841576644, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4952: J_gap = 12697.767929105192, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4953: J_gap = 12697.768014096075, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4954: J_gap = 12697.76809654521, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4955: J_gap = 12697.76817644885, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4956: J_gap = 12697.768253803595, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4957: J_gap = 12697.768328606377, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4958: J_gap = 12697.768400854458, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4959: J_gap = 12697.768470545454, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4960: J_gap = 12697.768537677304, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4961: J_gap = 12697.768602248289, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4962: J_gap = 12697.768664257017, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4963: J_gap = 12697.768723702444, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4964: J_gap = 12697.768780583845, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4965: J_gap = 12697.768834900842, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4966: J_gap = 12697.768886653379, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4967: J_gap = 12697.768935841734, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4968: J_gap = 12697.76898246652, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4969: J_gap = 12697.76902652867, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4970: J_gap = 12697.769068029455, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4971: J_gap = 12697.769106970467, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4972: J_gap = 12697.76914335363, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4973: J_gap = 12697.769177181186, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4974: J_gap = 12697.76920845571, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4975: J_gap = 12697.769237180088, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4976: J_gap = 12697.769263357543, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4977: J_gap = 12697.769286991608, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4978: J_gap = 12697.769308086135, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4979: J_gap = 12697.769326645302, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4980: J_gap = 12697.769342673591, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4981: J_gap = 12697.769356175815, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4982: J_gap = 12697.769367157087, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4983: J_gap = 12697.76937562284, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4984: J_gap = 12697.769381578808, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4985: J_gap = 12697.76938503105, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4986: J_gap = 12697.769385985925, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4987: J_gap = 12697.769384450086, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4988: J_gap = 12697.76938043051, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4989: J_gap = 12697.769373934465, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4990: J_gap = 12697.769364969527, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4991: J_gap = 12697.769353543557, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4992: J_gap = 12697.769339664732, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4993: J_gap = 12697.769323341516, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4994: J_gap = 12697.769304582656, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4995: J_gap = 12697.76928339721, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4996: J_gap = 12697.769259794519, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4997: J_gap = 12697.769233784204, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4998: J_gap = 12697.769205376178, tau = 6.5e-05, sigma = 2, theta = 1.0
# Iteration 4999: J_gap = 12697.769174580639, tau = 6.5e-05, sigma = 2, theta = 1.0
# Primal-dual method does not terminate after 36.66 seconds

# %%
for v in [ans1[0]]:
  # compute
  min_value = min(v)
  print(f'{min_value:.30f}')  # Print with 30 decimal places
# Out:
# 12697.752698619431612314656376838684

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files

#1) Set seaborn style ———
sns.set_style('darkgrid')
plt.rcParams['legend.facecolor'] = plt.rcParams['axes.facecolor']

#2) Define plot styles via rcParams ———
plt.rcParams.update({
    'font.size':        13,
    'figure.figsize':   (7, 5),
    'legend.fontsize':  16,
    'lines.linewidth':  2,
    'axes.labelsize':   16,
    'axes.titlesize':   10,
    'xtick.labelsize':  16,
    'ytick.labelsize':  16,
    'xtick.major.pad':  4,
    'ytick.major.pad':  4,
})

#3) Prepare the convergence data ----
values = [ans4[0], ans5[0], ans1[0], ans2[0]]
labels = ['aEGRPDA', 'P‑GRPDA', 'E‑GRPDA', 'Condat-Vu']
v_min = min(min(v) for v in values)
data = [np.array(v) - v_min for v in values]
iters = np.arange(len(data[0]))

#4) Define markers and size --
markers = ['D', 'o', 's', '*']
msize = 7

#5) Plot with markers --
plt.figure()
for y, lbl, c, m in zip(data, labels, ['#008080','#8A2BE2','black', 'red'], markers):
    plt.plot(iters, y,
             color=c, marker=m, markersize=msize,
             markevery=max(1, len(iters)//10), label=lbl)

plt.yscale('log')
plt.xlabel('Iterations')
plt.ylabel(r'$F(x_n)-F^*$')
plt.legend(framealpha=1.0)
plt.grid(True)
plt.tight_layout()
plt.savefig('log_scale_plot_comparison1.eps', dpi=600)
files.download('log_scale_plot_comparison1.eps')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#1) Style
sns.set_style('darkgrid')
plt.rcParams['legend.facecolor'] = plt.rcParams['axes.facecolor']
plt.rcParams.update({
    'font.size':        13,
    'figure.figsize':   (7, 5),
    'legend.fontsize':  16,
    'lines.linewidth':  2,
    'axes.labelsize':   16,
    'xtick.labelsize':  16,
    'ytick.labelsize':  16,
    'xtick.major.pad':  4,
    'ytick.major.pad':  4,
})

###################
_, _, _, _, sigma4, tau4 = ans4       # aEGRPDA
_, _, _, _, sigma1, tau1 = ans1       # E‑GRPDA
_, _, _, _, tau2, sigma2 = ans2       # Condat‑Vu

#3) Plot tau_n on log‐scale with light colors ----
plt.figure()
for tau_vals, label, color, marker in [
    (tau4, 'aEGRPDA',       '#EE82EE', 'o'),
    (tau1, 'E‑GRPDA',       '#20B2AA', 's'),
    (tau2, 'Condat‑Vu','blue', 'D'),
]:
    it = np.arange(len(tau_vals))
    me = max(1, len(it)//10)
    plt.plot(it, tau_vals,
             label=rf'{label}',
             color=color,
             marker=marker,
             markersize=7,
             markevery=me)

plt.yscale('log')
plt.xlabel('Iteration')
plt.ylabel(r'Primal Steps ($\tau_n$)')
plt.ylim([1e-5, 1e-1])
plt.legend(framealpha=1.0, loc='upper right')
plt.tight_layout()
plt.savefig('log_scale_plot_comparison1.eps', dpi=600)
files.download('log_scale_plot_comparison1.eps')
plt.show()

#4) Plot sigma_n on log‐scale with light colors
plt.figure()
for sigma_vals, label, color, marker in [
    (sigma4, 'aEGRPDA',       '#EE82EE', 'o'),
    (sigma1, 'E‑GRPDA',       '#20B2AA', 's'),
    (sigma2, 'Condat‑Vu', 'blue','D'),
]:
    it = np.arange(len(sigma_vals))
    me = max(1, len(it)//10)
    plt.plot(it, sigma_vals,
             label=rf'{label}',
             color=color,
             marker=marker,
             markersize=7,
             markevery=me)

plt.yscale('log')
plt.xlabel('Iteration')
plt.ylabel(r'Dual Steps ($\sigma_n$)')
plt.ylim([1e-1, 1e3])
plt.legend(framealpha=1.0, loc='upper right')
plt.tight_layout()
# plt.savefig('log_scale_plot_comparison1.eps', dpi=600)
# files.download('log_scale_plot_comparison1.eps')
plt.show()
